# %% [markdown]
# # Task 1: Feed-forward neural networks
#
#
# ---
#
# Tutorial: "Machine Learning in Solid Mechanics @ Cyber-Physical Simulation, TU Darmstadt
#
# Lecturer: Prof. Oliver Weeger
#
# Assistants: Dominik K. Klein, Jasper O. Schommartz
#
# Winter term 2024 / 2025
#
#
# ---

# %% [markdown]
# *Run the following cell to clone the GitHub repository in your current Google Colab environment.*

# %% [markdown]
# *Run the following cell to import all modules and python files to this notebook. If you made changes in the python files, run the following cell again to update the python files in this notebook. You might need to restart your Colab session first ("Runtime / Restart session" in the header menu).*

# %%
from matplotlib import pyplot as plt
import tensorflow as tf
import datetime
now = datetime.datetime.now

import importlib

# %% Own modules
import data as ld
importlib.reload(ld)
import models as lm
importlib.reload(lm)
# Out:
# <module 'models' from 'f:\\CPShub\\TutorialMLinSolidMechanics\\Winter_term_24_25\\FFNN_introduction_1.1\\models.py'>

# %% [markdown]
# ### Vary the number of hidden layers and nodes

# %%
model = lm.main()

xs, ys, xs_c, ys_c = ld.bathtub()

model.summary()

t1 = now()
print(t1)

model.optimizer.learning_rate.assign(0.002)
h = model.fit([xs_c], [ys_c], epochs = 500,  verbose = 2)

t2 = now()
print('it took', t2 - t1, '(sec) to calibrate the model')

# plot some results
plt.figure(1, dpi=150)
plt.semilogy(h.history['loss'], label='training loss')
plt.grid(which='both')
plt.xlabel('calibration epoch')
plt.ylabel('log$_{10}$ MSE')
plt.legend()

plt.figure(2, dpi=300)
plt.scatter(xs_c[::10], ys_c[::10], c='green', label = 'calibration data')
plt.plot(xs, ys, c='black', linestyle='--', label='bathtub function')
plt.plot(xs, model.predict(xs), label='model', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### Vary the number of epochs

# %%
from matplotlib import pyplot as plt
import tensorflow as tf
import datetime
now = datetime.datetime.now

import importlib

# %% Own modules
import data as ld
importlib.reload(ld)
import models as lm
importlib.reload(lm)
# Out:
# <module 'models' from 'f:\\CPShub\\TutorialMLinSolidMechanics\\Winter_term_24_25\\FFNN_introduction_1.1\\models.py'>

# %%
model = lm.main()

xs, ys, xs_c, ys_c = ld.bathtub()

model.summary()

t1 = now()
print(t1)

model.optimizer.learning_rate.assign(0.002)

#h = model.fit([xs_c], [ys_c], epochs = 500,  verbose = 2)
# h = model.fit([xs_c], [ys_c], epochs = 1000,  verbose = 2)
# h = model.fit([xs_c], [ys_c], epochs = 2500,  verbose = 2)
h = model.fit([xs_c], [ys_c], epochs = 5000,  verbose = 2)
t2 = now()
print('it took', t2 - t1, '(sec) to calibrate the model')

# plot some results
plt.figure(1, dpi=150)
plt.semilogy(h.history['loss'], label='training loss')
plt.grid(which='both')
plt.xlabel('calibration epoch')
plt.ylabel('log$_{10}$ MSE')
plt.legend()

plt.figure(2, dpi=300)
plt.scatter(xs_c[::10], ys_c[::10], c='green', label = 'calibration data')
plt.plot(xs, ys, c='black', linestyle='--', label='bathtub function')
plt.plot(xs, model.predict(xs), label='model', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 1)]               0
#
#  private_x_to_y_12 (_x_to_y)  (None, 1)                57
#
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# 2024-11-04 17:13:10.562005
# Epoch 1/5000
# 11/11 - 0s - loss: 1.9066 - 354ms/epoch - 32ms/step
# Epoch 2/5000
# 11/11 - 0s - loss: 0.9800 - 37ms/epoch - 3ms/step
# Epoch 3/5000
# 11/11 - 0s - loss: 0.4291 - 38ms/epoch - 3ms/step
# Epoch 4/5000
# 11/11 - 0s - loss: 0.1643 - 38ms/epoch - 3ms/step
# Epoch 5/5000
# 11/11 - 0s - loss: 0.0772 - 40ms/epoch - 4ms/step
# Epoch 6/5000
# 11/11 - 0s - loss: 0.0610 - 38ms/epoch - 3ms/step
# Epoch 7/5000
# 11/11 - 0s - loss: 0.0616 - 39ms/epoch - 4ms/step
# Epoch 8/5000
# 11/11 - 0s - loss: 0.0615 - 39ms/epoch - 4ms/step
# Epoch 9/5000
# 11/11 - 0s - loss: 0.0605 - 33ms/epoch - 3ms/step
# Epoch 10/5000
# 11/11 - 0s - loss: 0.0601 - 34ms/epoch - 3ms/step
# Epoch 11/5000
# 11/11 - 0s - loss: 0.0598 - 37ms/epoch - 3ms/step
# Epoch 12/5000
# 11/11 - 0s - loss: 0.0597 - 32ms/epoch - 3ms/step
# Epoch 13/5000
# 11/11 - 0s - loss: 0.0594 - 31ms/epoch - 3ms/step
# Epoch 14/5000
# 11/11 - 0s - loss: 0.0592 - 31ms/epoch - 3ms/step
# Epoch 15/5000
# 11/11 - 0s - loss: 0.0589 - 32ms/epoch - 3ms/step
# Epoch 16/5000
# 11/11 - 0s - loss: 0.0587 - 31ms/epoch - 3ms/step
# Epoch 17/5000
# 11/11 - 0s - loss: 0.0586 - 30ms/epoch - 3ms/step
# Epoch 18/5000
# 11/11 - 0s - loss: 0.0583 - 30ms/epoch - 3ms/step
# Epoch 19/5000
# 11/11 - 0s - loss: 0.0581 - 31ms/epoch - 3ms/step
# Epoch 20/5000
# 11/11 - 0s - loss: 0.0579 - 29ms/epoch - 3ms/step
# Epoch 21/5000
# 11/11 - 0s - loss: 0.0576 - 32ms/epoch - 3ms/step
# Epoch 22/5000
# 11/11 - 0s - loss: 0.0574 - 32ms/epoch - 3ms/step
# Epoch 23/5000
# 11/11 - 0s - loss: 0.0572 - 30ms/epoch - 3ms/step
# Epoch 24/5000
# 11/11 - 0s - loss: 0.0570 - 31ms/epoch - 3ms/step
# Epoch 25/5000
# 11/11 - 0s - loss: 0.0569 - 32ms/epoch - 3ms/step
# Epoch 26/5000
# 11/11 - 0s - loss: 0.0567 - 31ms/epoch - 3ms/step
# Epoch 27/5000
# 11/11 - 0s - loss: 0.0566 - 30ms/epoch - 3ms/step
# Epoch 28/5000
# 11/11 - 0s - loss: 0.0563 - 29ms/epoch - 3ms/step
# Epoch 29/5000
# 11/11 - 0s - loss: 0.0562 - 27ms/epoch - 2ms/step
# Epoch 30/5000
# 11/11 - 0s - loss: 0.0562 - 27ms/epoch - 2ms/step
# Epoch 31/5000
# 11/11 - 0s - loss: 0.0562 - 29ms/epoch - 3ms/step
# Epoch 32/5000
# 11/11 - 0s - loss: 0.0556 - 28ms/epoch - 3ms/step
# Epoch 33/5000
# 11/11 - 0s - loss: 0.0555 - 29ms/epoch - 3ms/step
# Epoch 34/5000
# 11/11 - 0s - loss: 0.0556 - 30ms/epoch - 3ms/step
# Epoch 35/5000
# 11/11 - 0s - loss: 0.0553 - 29ms/epoch - 3ms/step
# Epoch 36/5000
# 11/11 - 0s - loss: 0.0551 - 28ms/epoch - 3ms/step
# Epoch 37/5000
# 11/11 - 0s - loss: 0.0551 - 28ms/epoch - 3ms/step
# Epoch 38/5000
# 11/11 - 0s - loss: 0.0548 - 28ms/epoch - 3ms/step
# Epoch 39/5000
# 11/11 - 0s - loss: 0.0547 - 29ms/epoch - 3ms/step
# Epoch 40/5000
# 11/11 - 0s - loss: 0.0547 - 30ms/epoch - 3ms/step
# Epoch 41/5000
# 11/11 - 0s - loss: 0.0545 - 27ms/epoch - 2ms/step
# Epoch 42/5000
# 11/11 - 0s - loss: 0.0544 - 29ms/epoch - 3ms/step
# Epoch 43/5000
# 11/11 - 0s - loss: 0.0542 - 28ms/epoch - 3ms/step
# Epoch 44/5000
# 11/11 - 0s - loss: 0.0542 - 30ms/epoch - 3ms/step
# Epoch 45/5000
# 11/11 - 0s - loss: 0.0540 - 29ms/epoch - 3ms/step
# Epoch 46/5000
# 11/11 - 0s - loss: 0.0540 - 29ms/epoch - 3ms/step
# Epoch 47/5000
# 11/11 - 0s - loss: 0.0538 - 29ms/epoch - 3ms/step
# Epoch 48/5000
# 11/11 - 0s - loss: 0.0537 - 28ms/epoch - 3ms/step
# Epoch 49/5000
# 11/11 - 0s - loss: 0.0536 - 28ms/epoch - 3ms/step
# Epoch 50/5000
# 11/11 - 0s - loss: 0.0536 - 28ms/epoch - 3ms/step
# Epoch 51/5000
# 11/11 - 0s - loss: 0.0536 - 29ms/epoch - 3ms/step
# Epoch 52/5000
# 11/11 - 0s - loss: 0.0535 - 28ms/epoch - 3ms/step
# Epoch 53/5000
# 11/11 - 0s - loss: 0.0533 - 29ms/epoch - 3ms/step
# Epoch 54/5000
# 11/11 - 0s - loss: 0.0534 - 30ms/epoch - 3ms/step
# Epoch 55/5000
# 11/11 - 0s - loss: 0.0532 - 30ms/epoch - 3ms/step
# Epoch 56/5000
# 11/11 - 0s - loss: 0.0534 - 30ms/epoch - 3ms/step
# Epoch 57/5000
# 11/11 - 0s - loss: 0.0532 - 30ms/epoch - 3ms/step
# Epoch 58/5000
# 11/11 - 0s - loss: 0.0531 - 28ms/epoch - 3ms/step
# Epoch 59/5000
# 11/11 - 0s - loss: 0.0530 - 30ms/epoch - 3ms/step
# Epoch 60/5000
# 11/11 - 0s - loss: 0.0530 - 30ms/epoch - 3ms/step
# Epoch 61/5000
# 11/11 - 0s - loss: 0.0528 - 29ms/epoch - 3ms/step
# Epoch 62/5000
# 11/11 - 0s - loss: 0.0529 - 29ms/epoch - 3ms/step
# Epoch 63/5000
# 11/11 - 0s - loss: 0.0528 - 30ms/epoch - 3ms/step
# Epoch 64/5000
# 11/11 - 0s - loss: 0.0528 - 28ms/epoch - 3ms/step
# Epoch 65/5000
# 11/11 - 0s - loss: 0.0528 - 26ms/epoch - 2ms/step
# Epoch 66/5000
# 11/11 - 0s - loss: 0.0529 - 26ms/epoch - 2ms/step
# Epoch 67/5000
# 11/11 - 0s - loss: 0.0528 - 30ms/epoch - 3ms/step
# Epoch 68/5000
# 11/11 - 0s - loss: 0.0526 - 30ms/epoch - 3ms/step
# Epoch 69/5000
# 11/11 - 0s - loss: 0.0527 - 30ms/epoch - 3ms/step
# Epoch 70/5000
# 11/11 - 0s - loss: 0.0526 - 29ms/epoch - 3ms/step
# Epoch 71/5000
# 11/11 - 0s - loss: 0.0525 - 30ms/epoch - 3ms/step
# Epoch 72/5000
# 11/11 - 0s - loss: 0.0526 - 29ms/epoch - 3ms/step
# Epoch 73/5000
# 11/11 - 0s - loss: 0.0526 - 28ms/epoch - 3ms/step
# Epoch 74/5000
# 11/11 - 0s - loss: 0.0525 - 27ms/epoch - 2ms/step
# Epoch 75/5000
# 11/11 - 0s - loss: 0.0524 - 30ms/epoch - 3ms/step
# Epoch 76/5000
# 11/11 - 0s - loss: 0.0525 - 29ms/epoch - 3ms/step
# Epoch 77/5000
# 11/11 - 0s - loss: 0.0522 - 30ms/epoch - 3ms/step
# Epoch 78/5000
# 11/11 - 0s - loss: 0.0524 - 31ms/epoch - 3ms/step
# Epoch 79/5000
# 11/11 - 0s - loss: 0.0524 - 39ms/epoch - 4ms/step
# Epoch 80/5000
# 11/11 - 0s - loss: 0.0524 - 33ms/epoch - 3ms/step
# Epoch 81/5000
# 11/11 - 0s - loss: 0.0523 - 29ms/epoch - 3ms/step
# Epoch 82/5000
# 11/11 - 0s - loss: 0.0523 - 27ms/epoch - 2ms/step
# Epoch 83/5000
# 11/11 - 0s - loss: 0.0523 - 29ms/epoch - 3ms/step
# Epoch 84/5000
# 11/11 - 0s - loss: 0.0523 - 29ms/epoch - 3ms/step
# Epoch 85/5000
# 11/11 - 0s - loss: 0.0521 - 31ms/epoch - 3ms/step
# Epoch 86/5000
# 11/11 - 0s - loss: 0.0525 - 33ms/epoch - 3ms/step
# Epoch 87/5000
# 11/11 - 0s - loss: 0.0522 - 29ms/epoch - 3ms/step
# Epoch 88/5000
# 11/11 - 0s - loss: 0.0526 - 31ms/epoch - 3ms/step
# Epoch 89/5000
# 11/11 - 0s - loss: 0.0522 - 32ms/epoch - 3ms/step
# Epoch 90/5000
# 11/11 - 0s - loss: 0.0521 - 32ms/epoch - 3ms/step
# Epoch 91/5000
# 11/11 - 0s - loss: 0.0524 - 29ms/epoch - 3ms/step
# Epoch 92/5000
# 11/11 - 0s - loss: 0.0521 - 31ms/epoch - 3ms/step
# Epoch 93/5000
# 11/11 - 0s - loss: 0.0521 - 29ms/epoch - 3ms/step
# Epoch 94/5000
# 11/11 - 0s - loss: 0.0522 - 29ms/epoch - 3ms/step
# Epoch 95/5000
# 11/11 - 0s - loss: 0.0521 - 29ms/epoch - 3ms/step
# Epoch 96/5000
# 11/11 - 0s - loss: 0.0522 - 30ms/epoch - 3ms/step
# Epoch 97/5000
# 11/11 - 0s - loss: 0.0521 - 30ms/epoch - 3ms/step
# Epoch 98/5000
# 11/11 - 0s - loss: 0.0521 - 30ms/epoch - 3ms/step
# Epoch 99/5000
# 11/11 - 0s - loss: 0.0521 - 29ms/epoch - 3ms/step
# Epoch 100/5000
# 11/11 - 0s - loss: 0.0520 - 30ms/epoch - 3ms/step
# Epoch 101/5000
# 11/11 - 0s - loss: 0.0521 - 28ms/epoch - 3ms/step
# Epoch 102/5000
# 11/11 - 0s - loss: 0.0519 - 31ms/epoch - 3ms/step
# Epoch 103/5000
# 11/11 - 0s - loss: 0.0521 - 31ms/epoch - 3ms/step
# Epoch 104/5000
# 11/11 - 0s - loss: 0.0520 - 29ms/epoch - 3ms/step
# Epoch 105/5000
# 11/11 - 0s - loss: 0.0523 - 28ms/epoch - 3ms/step
# Epoch 106/5000
# 11/11 - 0s - loss: 0.0517 - 29ms/epoch - 3ms/step
# Epoch 107/5000
# 11/11 - 0s - loss: 0.0521 - 29ms/epoch - 3ms/step
# Epoch 108/5000
# 11/11 - 0s - loss: 0.0522 - 30ms/epoch - 3ms/step
# Epoch 109/5000
# 11/11 - 0s - loss: 0.0519 - 30ms/epoch - 3ms/step
# Epoch 110/5000
# 11/11 - 0s - loss: 0.0519 - 32ms/epoch - 3ms/step
# Epoch 111/5000
# 11/11 - 0s - loss: 0.0519 - 29ms/epoch - 3ms/step
# Epoch 112/5000
# 11/11 - 0s - loss: 0.0518 - 30ms/epoch - 3ms/step
# Epoch 113/5000
# 11/11 - 0s - loss: 0.0519 - 29ms/epoch - 3ms/step
# Epoch 114/5000
# 11/11 - 0s - loss: 0.0519 - 29ms/epoch - 3ms/step
# Epoch 115/5000
# 11/11 - 0s - loss: 0.0520 - 29ms/epoch - 3ms/step
# Epoch 116/5000
# 11/11 - 0s - loss: 0.0519 - 29ms/epoch - 3ms/step
# Epoch 117/5000
# 11/11 - 0s - loss: 0.0520 - 30ms/epoch - 3ms/step
# Epoch 118/5000
# 11/11 - 0s - loss: 0.0519 - 29ms/epoch - 3ms/step
# Epoch 119/5000
# 11/11 - 0s - loss: 0.0519 - 28ms/epoch - 3ms/step
# Epoch 120/5000
# 11/11 - 0s - loss: 0.0517 - 30ms/epoch - 3ms/step
# Epoch 121/5000
# 11/11 - 0s - loss: 0.0520 - 27ms/epoch - 2ms/step
# Epoch 122/5000
# 11/11 - 0s - loss: 0.0521 - 28ms/epoch - 3ms/step
# Epoch 123/5000
# 11/11 - 0s - loss: 0.0516 - 29ms/epoch - 3ms/step
# Epoch 124/5000
# 11/11 - 0s - loss: 0.0521 - 29ms/epoch - 3ms/step
# Epoch 125/5000
# 11/11 - 0s - loss: 0.0518 - 31ms/epoch - 3ms/step
# Epoch 126/5000
# 11/11 - 0s - loss: 0.0519 - 31ms/epoch - 3ms/step
# Epoch 127/5000
# 11/11 - 0s - loss: 0.0517 - 29ms/epoch - 3ms/step
# Epoch 128/5000
# 11/11 - 0s - loss: 0.0516 - 29ms/epoch - 3ms/step
# Epoch 129/5000
# 11/11 - 0s - loss: 0.0518 - 28ms/epoch - 3ms/step
# Epoch 130/5000
# 11/11 - 0s - loss: 0.0518 - 32ms/epoch - 3ms/step
# Epoch 131/5000
# 11/11 - 0s - loss: 0.0516 - 29ms/epoch - 3ms/step
# Epoch 132/5000
# 11/11 - 0s - loss: 0.0517 - 29ms/epoch - 3ms/step
# Epoch 133/5000
# 11/11 - 0s - loss: 0.0518 - 29ms/epoch - 3ms/step
# Epoch 134/5000
# 11/11 - 0s - loss: 0.0520 - 31ms/epoch - 3ms/step
# Epoch 135/5000
# 11/11 - 0s - loss: 0.0516 - 30ms/epoch - 3ms/step
# Epoch 136/5000
# 11/11 - 0s - loss: 0.0516 - 29ms/epoch - 3ms/step
# Epoch 137/5000
# 11/11 - 0s - loss: 0.0517 - 29ms/epoch - 3ms/step
# Epoch 138/5000
# 11/11 - 0s - loss: 0.0515 - 30ms/epoch - 3ms/step
# Epoch 139/5000
# 11/11 - 0s - loss: 0.0518 - 27ms/epoch - 2ms/step
# Epoch 140/5000
# 11/11 - 0s - loss: 0.0515 - 30ms/epoch - 3ms/step
# Epoch 141/5000
# 11/11 - 0s - loss: 0.0527 - 30ms/epoch - 3ms/step
# Epoch 142/5000
# 11/11 - 0s - loss: 0.0517 - 29ms/epoch - 3ms/step
# Epoch 143/5000
# 11/11 - 0s - loss: 0.0514 - 29ms/epoch - 3ms/step
# Epoch 144/5000
# 11/11 - 0s - loss: 0.0522 - 31ms/epoch - 3ms/step
# Epoch 145/5000
# 11/11 - 0s - loss: 0.0514 - 28ms/epoch - 3ms/step
# Epoch 146/5000
# 11/11 - 0s - loss: 0.0516 - 29ms/epoch - 3ms/step
# Epoch 147/5000
# 11/11 - 0s - loss: 0.0517 - 30ms/epoch - 3ms/step
# Epoch 148/5000
# 11/11 - 0s - loss: 0.0514 - 30ms/epoch - 3ms/step
# Epoch 149/5000
# 11/11 - 0s - loss: 0.0515 - 31ms/epoch - 3ms/step
# Epoch 150/5000
# 11/11 - 0s - loss: 0.0516 - 32ms/epoch - 3ms/step
# Epoch 151/5000
# 11/11 - 0s - loss: 0.0515 - 31ms/epoch - 3ms/step
# Epoch 152/5000
# 11/11 - 0s - loss: 0.0514 - 31ms/epoch - 3ms/step
# Epoch 153/5000
# 11/11 - 0s - loss: 0.0519 - 28ms/epoch - 3ms/step
# Epoch 154/5000
# 11/11 - 0s - loss: 0.0528 - 31ms/epoch - 3ms/step
# Epoch 155/5000
# 11/11 - 0s - loss: 0.0517 - 33ms/epoch - 3ms/step
# Epoch 156/5000
# 11/11 - 0s - loss: 0.0515 - 29ms/epoch - 3ms/step
# Epoch 157/5000
# 11/11 - 0s - loss: 0.0514 - 30ms/epoch - 3ms/step
# Epoch 158/5000
# 11/11 - 0s - loss: 0.0512 - 38ms/epoch - 3ms/step
# Epoch 159/5000
# 11/11 - 0s - loss: 0.0512 - 36ms/epoch - 3ms/step
# Epoch 160/5000
# 11/11 - 0s - loss: 0.0517 - 40ms/epoch - 4ms/step
# Epoch 161/5000
# 11/11 - 0s - loss: 0.0508 - 39ms/epoch - 4ms/step
# Epoch 162/5000
# 11/11 - 0s - loss: 0.0517 - 31ms/epoch - 3ms/step
# Epoch 163/5000
# 11/11 - 0s - loss: 0.0510 - 31ms/epoch - 3ms/step
# Epoch 164/5000
# 11/11 - 0s - loss: 0.0510 - 29ms/epoch - 3ms/step
# Epoch 165/5000
# 11/11 - 0s - loss: 0.0510 - 28ms/epoch - 3ms/step
# Epoch 166/5000
# 11/11 - 0s - loss: 0.0511 - 29ms/epoch - 3ms/step
# Epoch 167/5000
# 11/11 - 0s - loss: 0.0510 - 29ms/epoch - 3ms/step
# Epoch 168/5000
# 11/11 - 0s - loss: 0.0510 - 30ms/epoch - 3ms/step
# Epoch 169/5000
# 11/11 - 0s - loss: 0.0511 - 29ms/epoch - 3ms/step
# Epoch 170/5000
# 11/11 - 0s - loss: 0.0509 - 32ms/epoch - 3ms/step
# Epoch 171/5000
# 11/11 - 0s - loss: 0.0507 - 27ms/epoch - 2ms/step
# Epoch 172/5000
# 11/11 - 0s - loss: 0.0509 - 31ms/epoch - 3ms/step
# Epoch 173/5000
# 11/11 - 0s - loss: 0.0508 - 30ms/epoch - 3ms/step
# Epoch 174/5000
# 11/11 - 0s - loss: 0.0510 - 30ms/epoch - 3ms/step
# Epoch 175/5000
# 11/11 - 0s - loss: 0.0513 - 28ms/epoch - 3ms/step
# Epoch 176/5000
# 11/11 - 0s - loss: 0.0514 - 28ms/epoch - 3ms/step
# Epoch 177/5000
# 11/11 - 0s - loss: 0.0505 - 29ms/epoch - 3ms/step
# Epoch 178/5000
# 11/11 - 0s - loss: 0.0510 - 28ms/epoch - 3ms/step
# Epoch 179/5000
# 11/11 - 0s - loss: 0.0507 - 28ms/epoch - 3ms/step
# Epoch 180/5000
# 11/11 - 0s - loss: 0.0510 - 30ms/epoch - 3ms/step
# Epoch 181/5000
# 11/11 - 0s - loss: 0.0515 - 34ms/epoch - 3ms/step
# Epoch 182/5000
# 11/11 - 0s - loss: 0.0504 - 35ms/epoch - 3ms/step
# Epoch 183/5000
# 11/11 - 0s - loss: 0.0504 - 27ms/epoch - 2ms/step
# Epoch 184/5000
# 11/11 - 0s - loss: 0.0504 - 33ms/epoch - 3ms/step
# Epoch 185/5000
# 11/11 - 0s - loss: 0.0504 - 29ms/epoch - 3ms/step
# Epoch 186/5000
# 11/11 - 0s - loss: 0.0503 - 28ms/epoch - 3ms/step
# Epoch 187/5000
# 11/11 - 0s - loss: 0.0505 - 31ms/epoch - 3ms/step
# Epoch 188/5000
# 11/11 - 0s - loss: 0.0502 - 42ms/epoch - 4ms/step
# Epoch 189/5000
# 11/11 - 0s - loss: 0.0510 - 35ms/epoch - 3ms/step
# Epoch 190/5000
# 11/11 - 0s - loss: 0.0503 - 32ms/epoch - 3ms/step
# Epoch 191/5000
# 11/11 - 0s - loss: 0.0503 - 30ms/epoch - 3ms/step
# Epoch 192/5000
# 11/11 - 0s - loss: 0.0501 - 31ms/epoch - 3ms/step
# Epoch 193/5000
# 11/11 - 0s - loss: 0.0510 - 30ms/epoch - 3ms/step
# Epoch 194/5000
# 11/11 - 0s - loss: 0.0510 - 29ms/epoch - 3ms/step
# Epoch 195/5000
# 11/11 - 0s - loss: 0.0498 - 35ms/epoch - 3ms/step
# Epoch 196/5000
# 11/11 - 0s - loss: 0.0499 - 32ms/epoch - 3ms/step
# Epoch 197/5000
# 11/11 - 0s - loss: 0.0498 - 29ms/epoch - 3ms/step
# Epoch 198/5000
# 11/11 - 0s - loss: 0.0497 - 30ms/epoch - 3ms/step
# Epoch 199/5000
# 11/11 - 0s - loss: 0.0496 - 32ms/epoch - 3ms/step
# Epoch 200/5000
# 11/11 - 0s - loss: 0.0499 - 30ms/epoch - 3ms/step
# Epoch 201/5000
# 11/11 - 0s - loss: 0.0495 - 29ms/epoch - 3ms/step
# Epoch 202/5000
# 11/11 - 0s - loss: 0.0498 - 29ms/epoch - 3ms/step
# Epoch 203/5000
# 11/11 - 0s - loss: 0.0499 - 29ms/epoch - 3ms/step
# Epoch 204/5000
# 11/11 - 0s - loss: 0.0493 - 28ms/epoch - 3ms/step
# Epoch 205/5000
# 11/11 - 0s - loss: 0.0493 - 28ms/epoch - 3ms/step
# Epoch 206/5000
# 11/11 - 0s - loss: 0.0499 - 31ms/epoch - 3ms/step
# Epoch 207/5000
# 11/11 - 0s - loss: 0.0492 - 30ms/epoch - 3ms/step
# Epoch 208/5000
# 11/11 - 0s - loss: 0.0502 - 28ms/epoch - 3ms/step
# Epoch 209/5000
# 11/11 - 0s - loss: 0.0491 - 31ms/epoch - 3ms/step
# Epoch 210/5000
# 11/11 - 0s - loss: 0.0489 - 29ms/epoch - 3ms/step
# Epoch 211/5000
# 11/11 - 0s - loss: 0.0489 - 29ms/epoch - 3ms/step
# Epoch 212/5000
# 11/11 - 0s - loss: 0.0488 - 27ms/epoch - 2ms/step
# Epoch 213/5000
# 11/11 - 0s - loss: 0.0488 - 27ms/epoch - 2ms/step
# Epoch 214/5000
# 11/11 - 0s - loss: 0.0485 - 27ms/epoch - 2ms/step
# Epoch 215/5000
# 11/11 - 0s - loss: 0.0491 - 30ms/epoch - 3ms/step
# Epoch 216/5000
# 11/11 - 0s - loss: 0.0483 - 29ms/epoch - 3ms/step
# Epoch 217/5000
# 11/11 - 0s - loss: 0.0482 - 28ms/epoch - 3ms/step
# Epoch 218/5000
# 11/11 - 0s - loss: 0.0481 - 28ms/epoch - 3ms/step
# Epoch 219/5000
# 11/11 - 0s - loss: 0.0481 - 29ms/epoch - 3ms/step
# Epoch 220/5000
# 11/11 - 0s - loss: 0.0483 - 33ms/epoch - 3ms/step
# Epoch 221/5000
# 11/11 - 0s - loss: 0.0481 - 31ms/epoch - 3ms/step
# Epoch 222/5000
# 11/11 - 0s - loss: 0.0479 - 32ms/epoch - 3ms/step
# Epoch 223/5000
# 11/11 - 0s - loss: 0.0476 - 30ms/epoch - 3ms/step
# Epoch 224/5000
# 11/11 - 0s - loss: 0.0477 - 28ms/epoch - 3ms/step
# Epoch 225/5000
# 11/11 - 0s - loss: 0.0476 - 29ms/epoch - 3ms/step
# Epoch 226/5000
# 11/11 - 0s - loss: 0.0474 - 28ms/epoch - 3ms/step
# Epoch 227/5000
# 11/11 - 0s - loss: 0.0471 - 29ms/epoch - 3ms/step
# Epoch 228/5000
# 11/11 - 0s - loss: 0.0474 - 28ms/epoch - 3ms/step
# Epoch 229/5000
# 11/11 - 0s - loss: 0.0471 - 29ms/epoch - 3ms/step
# Epoch 230/5000
# 11/11 - 0s - loss: 0.0473 - 29ms/epoch - 3ms/step
# Epoch 231/5000
# 11/11 - 0s - loss: 0.0470 - 28ms/epoch - 3ms/step
# Epoch 232/5000
# 11/11 - 0s - loss: 0.0474 - 30ms/epoch - 3ms/step
# Epoch 233/5000
# 11/11 - 0s - loss: 0.0487 - 28ms/epoch - 3ms/step
# Epoch 234/5000
# 11/11 - 0s - loss: 0.0463 - 29ms/epoch - 3ms/step
# Epoch 235/5000
# 11/11 - 0s - loss: 0.0463 - 29ms/epoch - 3ms/step
# Epoch 236/5000
# 11/11 - 0s - loss: 0.0460 - 28ms/epoch - 3ms/step
# Epoch 237/5000
# 11/11 - 0s - loss: 0.0459 - 28ms/epoch - 3ms/step
# Epoch 238/5000
# 11/11 - 0s - loss: 0.0457 - 30ms/epoch - 3ms/step
# Epoch 239/5000
# 11/11 - 0s - loss: 0.0454 - 30ms/epoch - 3ms/step
# Epoch 240/5000
# 11/11 - 0s - loss: 0.0452 - 28ms/epoch - 3ms/step
# Epoch 241/5000
# 11/11 - 0s - loss: 0.0456 - 30ms/epoch - 3ms/step
# Epoch 242/5000
# 11/11 - 0s - loss: 0.0454 - 30ms/epoch - 3ms/step
# Epoch 243/5000
# 11/11 - 0s - loss: 0.0446 - 28ms/epoch - 3ms/step
# Epoch 244/5000
# 11/11 - 0s - loss: 0.0447 - 29ms/epoch - 3ms/step
# Epoch 245/5000
# 11/11 - 0s - loss: 0.0448 - 29ms/epoch - 3ms/step
# Epoch 246/5000
# 11/11 - 0s - loss: 0.0440 - 28ms/epoch - 3ms/step
# Epoch 247/5000
# 11/11 - 0s - loss: 0.0438 - 29ms/epoch - 3ms/step
# Epoch 248/5000
# 11/11 - 0s - loss: 0.0435 - 29ms/epoch - 3ms/step
# Epoch 249/5000
# 11/11 - 0s - loss: 0.0435 - 29ms/epoch - 3ms/step
# Epoch 250/5000
# 11/11 - 0s - loss: 0.0432 - 30ms/epoch - 3ms/step
# Epoch 251/5000
# 11/11 - 0s - loss: 0.0432 - 29ms/epoch - 3ms/step
# Epoch 252/5000
# 11/11 - 0s - loss: 0.0427 - 29ms/epoch - 3ms/step
# Epoch 253/5000
# 11/11 - 0s - loss: 0.0427 - 29ms/epoch - 3ms/step
# Epoch 254/5000
# 11/11 - 0s - loss: 0.0429 - 30ms/epoch - 3ms/step
# Epoch 255/5000
# 11/11 - 0s - loss: 0.0424 - 30ms/epoch - 3ms/step
# Epoch 256/5000
# 11/11 - 0s - loss: 0.0420 - 29ms/epoch - 3ms/step
# Epoch 257/5000
# 11/11 - 0s - loss: 0.0419 - 28ms/epoch - 3ms/step
# Epoch 258/5000
# 11/11 - 0s - loss: 0.0418 - 28ms/epoch - 3ms/step
# Epoch 259/5000
# 11/11 - 0s - loss: 0.0409 - 31ms/epoch - 3ms/step
# Epoch 260/5000
# 11/11 - 0s - loss: 0.0404 - 28ms/epoch - 3ms/step
# Epoch 261/5000
# 11/11 - 0s - loss: 0.0403 - 29ms/epoch - 3ms/step
# Epoch 262/5000
# 11/11 - 0s - loss: 0.0400 - 31ms/epoch - 3ms/step
# Epoch 263/5000
# 11/11 - 0s - loss: 0.0398 - 30ms/epoch - 3ms/step
# Epoch 264/5000
# 11/11 - 0s - loss: 0.0391 - 29ms/epoch - 3ms/step
# Epoch 265/5000
# 11/11 - 0s - loss: 0.0388 - 31ms/epoch - 3ms/step
# Epoch 266/5000
# 11/11 - 0s - loss: 0.0384 - 29ms/epoch - 3ms/step
# Epoch 267/5000
# 11/11 - 0s - loss: 0.0381 - 29ms/epoch - 3ms/step
# Epoch 268/5000
# 11/11 - 0s - loss: 0.0385 - 27ms/epoch - 2ms/step
# Epoch 269/5000
# 11/11 - 0s - loss: 0.0381 - 28ms/epoch - 3ms/step
# Epoch 270/5000
# 11/11 - 0s - loss: 0.0369 - 28ms/epoch - 3ms/step
# Epoch 271/5000
# 11/11 - 0s - loss: 0.0370 - 30ms/epoch - 3ms/step
# Epoch 272/5000
# 11/11 - 0s - loss: 0.0362 - 31ms/epoch - 3ms/step
# Epoch 273/5000
# 11/11 - 0s - loss: 0.0361 - 30ms/epoch - 3ms/step
# Epoch 274/5000
# 11/11 - 0s - loss: 0.0352 - 29ms/epoch - 3ms/step
# Epoch 275/5000
# 11/11 - 0s - loss: 0.0349 - 28ms/epoch - 3ms/step
# Epoch 276/5000
# 11/11 - 0s - loss: 0.0347 - 29ms/epoch - 3ms/step
# Epoch 277/5000
# 11/11 - 0s - loss: 0.0339 - 30ms/epoch - 3ms/step
# Epoch 278/5000
# 11/11 - 0s - loss: 0.0336 - 28ms/epoch - 3ms/step
# Epoch 279/5000
# 11/11 - 0s - loss: 0.0334 - 27ms/epoch - 2ms/step
# Epoch 280/5000
# 11/11 - 0s - loss: 0.0326 - 27ms/epoch - 2ms/step
# Epoch 281/5000
# 11/11 - 0s - loss: 0.0321 - 29ms/epoch - 3ms/step
# Epoch 282/5000
# 11/11 - 0s - loss: 0.0320 - 28ms/epoch - 3ms/step
# Epoch 283/5000
# 11/11 - 0s - loss: 0.0315 - 30ms/epoch - 3ms/step
# Epoch 284/5000
# 11/11 - 0s - loss: 0.0305 - 29ms/epoch - 3ms/step
# Epoch 285/5000
# 11/11 - 0s - loss: 0.0302 - 29ms/epoch - 3ms/step
# Epoch 286/5000
# 11/11 - 0s - loss: 0.0300 - 29ms/epoch - 3ms/step
# Epoch 287/5000
# 11/11 - 0s - loss: 0.0289 - 29ms/epoch - 3ms/step
# Epoch 288/5000
# 11/11 - 0s - loss: 0.0281 - 28ms/epoch - 3ms/step
# Epoch 289/5000
# 11/11 - 0s - loss: 0.0279 - 29ms/epoch - 3ms/step
# Epoch 290/5000
# 11/11 - 0s - loss: 0.0285 - 30ms/epoch - 3ms/step
# Epoch 291/5000
# 11/11 - 0s - loss: 0.0285 - 31ms/epoch - 3ms/step
# Epoch 292/5000
# 11/11 - 0s - loss: 0.0273 - 30ms/epoch - 3ms/step
# Epoch 293/5000
# 11/11 - 0s - loss: 0.0256 - 32ms/epoch - 3ms/step
# Epoch 294/5000
# 11/11 - 0s - loss: 0.0248 - 29ms/epoch - 3ms/step
# Epoch 295/5000
# 11/11 - 0s - loss: 0.0245 - 30ms/epoch - 3ms/step
# Epoch 296/5000
# 11/11 - 0s - loss: 0.0237 - 29ms/epoch - 3ms/step
# Epoch 297/5000
# 11/11 - 0s - loss: 0.0230 - 30ms/epoch - 3ms/step
# Epoch 298/5000
# 11/11 - 0s - loss: 0.0225 - 31ms/epoch - 3ms/step
# Epoch 299/5000
# 11/11 - 0s - loss: 0.0218 - 29ms/epoch - 3ms/step
# Epoch 300/5000
# 11/11 - 0s - loss: 0.0215 - 29ms/epoch - 3ms/step
# Epoch 301/5000
# 11/11 - 0s - loss: 0.0208 - 30ms/epoch - 3ms/step
# Epoch 302/5000
# 11/11 - 0s - loss: 0.0202 - 49ms/epoch - 4ms/step
# Epoch 303/5000
# 11/11 - 0s - loss: 0.0197 - 33ms/epoch - 3ms/step
# Epoch 304/5000
# 11/11 - 0s - loss: 0.0190 - 36ms/epoch - 3ms/step
# Epoch 305/5000
# 11/11 - 0s - loss: 0.0182 - 29ms/epoch - 3ms/step
# Epoch 306/5000
# 11/11 - 0s - loss: 0.0179 - 28ms/epoch - 3ms/step
# Epoch 307/5000
# 11/11 - 0s - loss: 0.0176 - 33ms/epoch - 3ms/step
# Epoch 308/5000
# 11/11 - 0s - loss: 0.0167 - 32ms/epoch - 3ms/step
# Epoch 309/5000
# 11/11 - 0s - loss: 0.0158 - 37ms/epoch - 3ms/step
# Epoch 310/5000
# 11/11 - 0s - loss: 0.0152 - 38ms/epoch - 3ms/step
# Epoch 311/5000
# 11/11 - 0s - loss: 0.0148 - 30ms/epoch - 3ms/step
# Epoch 312/5000
# 11/11 - 0s - loss: 0.0142 - 41ms/epoch - 4ms/step
# Epoch 313/5000
# 11/11 - 0s - loss: 0.0140 - 47ms/epoch - 4ms/step
# Epoch 314/5000
# 11/11 - 0s - loss: 0.0131 - 39ms/epoch - 4ms/step
# Epoch 315/5000
# 11/11 - 0s - loss: 0.0127 - 34ms/epoch - 3ms/step
# Epoch 316/5000
# 11/11 - 0s - loss: 0.0120 - 31ms/epoch - 3ms/step
# Epoch 317/5000
# 11/11 - 0s - loss: 0.0120 - 30ms/epoch - 3ms/step
# Epoch 318/5000
# 11/11 - 0s - loss: 0.0111 - 31ms/epoch - 3ms/step
# Epoch 319/5000
# 11/11 - 0s - loss: 0.0105 - 32ms/epoch - 3ms/step
# Epoch 320/5000
# 11/11 - 0s - loss: 0.0102 - 31ms/epoch - 3ms/step
# Epoch 321/5000
# 11/11 - 0s - loss: 0.0096 - 29ms/epoch - 3ms/step
# Epoch 322/5000
# 11/11 - 0s - loss: 0.0096 - 31ms/epoch - 3ms/step
# Epoch 323/5000
# 11/11 - 0s - loss: 0.0088 - 34ms/epoch - 3ms/step
# Epoch 324/5000
# 11/11 - 0s - loss: 0.0084 - 32ms/epoch - 3ms/step
# Epoch 325/5000
# 11/11 - 0s - loss: 0.0080 - 32ms/epoch - 3ms/step
# Epoch 326/5000
# 11/11 - 0s - loss: 0.0076 - 35ms/epoch - 3ms/step
# Epoch 327/5000
# 11/11 - 0s - loss: 0.0074 - 35ms/epoch - 3ms/step
# Epoch 328/5000
# 11/11 - 0s - loss: 0.0070 - 34ms/epoch - 3ms/step
# Epoch 329/5000
# 11/11 - 0s - loss: 0.0068 - 33ms/epoch - 3ms/step
# Epoch 330/5000
# 11/11 - 0s - loss: 0.0065 - 33ms/epoch - 3ms/step
# Epoch 331/5000
# 11/11 - 0s - loss: 0.0063 - 31ms/epoch - 3ms/step
# Epoch 332/5000
# 11/11 - 0s - loss: 0.0064 - 32ms/epoch - 3ms/step
# Epoch 333/5000
# 11/11 - 0s - loss: 0.0058 - 31ms/epoch - 3ms/step
# Epoch 334/5000
# 11/11 - 0s - loss: 0.0056 - 31ms/epoch - 3ms/step
# Epoch 335/5000
# 11/11 - 0s - loss: 0.0053 - 31ms/epoch - 3ms/step
# Epoch 336/5000
# 11/11 - 0s - loss: 0.0051 - 30ms/epoch - 3ms/step
# Epoch 337/5000
# 11/11 - 0s - loss: 0.0048 - 32ms/epoch - 3ms/step
# Epoch 338/5000
# 11/11 - 0s - loss: 0.0048 - 30ms/epoch - 3ms/step
# Epoch 339/5000
# 11/11 - 0s - loss: 0.0046 - 30ms/epoch - 3ms/step
# Epoch 340/5000
# 11/11 - 0s - loss: 0.0044 - 30ms/epoch - 3ms/step
# Epoch 341/5000
# 11/11 - 0s - loss: 0.0044 - 31ms/epoch - 3ms/step
# Epoch 342/5000
# 11/11 - 0s - loss: 0.0043 - 30ms/epoch - 3ms/step
# Epoch 343/5000
# 11/11 - 0s - loss: 0.0041 - 32ms/epoch - 3ms/step
# Epoch 344/5000
# 11/11 - 0s - loss: 0.0041 - 34ms/epoch - 3ms/step
# Epoch 345/5000
# 11/11 - 0s - loss: 0.0040 - 62ms/epoch - 6ms/step
# Epoch 346/5000
# 11/11 - 0s - loss: 0.0042 - 51ms/epoch - 5ms/step
# Epoch 347/5000
# 11/11 - 0s - loss: 0.0037 - 46ms/epoch - 4ms/step
# Epoch 348/5000
# 11/11 - 0s - loss: 0.0037 - 45ms/epoch - 4ms/step
# Epoch 349/5000
# 11/11 - 0s - loss: 0.0036 - 40ms/epoch - 4ms/step
# Epoch 350/5000
# 11/11 - 0s - loss: 0.0037 - 41ms/epoch - 4ms/step
# Epoch 351/5000
# 11/11 - 0s - loss: 0.0038 - 44ms/epoch - 4ms/step
# Epoch 352/5000
# 11/11 - 0s - loss: 0.0037 - 42ms/epoch - 4ms/step
# Epoch 353/5000
# 11/11 - 0s - loss: 0.0034 - 43ms/epoch - 4ms/step
# Epoch 354/5000
# 11/11 - 0s - loss: 0.0036 - 38ms/epoch - 3ms/step
# Epoch 355/5000
# 11/11 - 0s - loss: 0.0034 - 35ms/epoch - 3ms/step
# Epoch 356/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 357/5000
# 11/11 - 0s - loss: 0.0034 - 35ms/epoch - 3ms/step
# Epoch 358/5000
# 11/11 - 0s - loss: 0.0034 - 43ms/epoch - 4ms/step
# Epoch 359/5000
# 11/11 - 0s - loss: 0.0033 - 39ms/epoch - 4ms/step
# Epoch 360/5000
# 11/11 - 0s - loss: 0.0035 - 39ms/epoch - 4ms/step
# Epoch 361/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 362/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 363/5000
# 11/11 - 0s - loss: 0.0034 - 40ms/epoch - 4ms/step
# Epoch 364/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 365/5000
# 11/11 - 0s - loss: 0.0032 - 39ms/epoch - 4ms/step
# Epoch 366/5000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 367/5000
# 11/11 - 0s - loss: 0.0034 - 40ms/epoch - 4ms/step
# Epoch 368/5000
# 11/11 - 0s - loss: 0.0035 - 39ms/epoch - 4ms/step
# Epoch 369/5000
# 11/11 - 0s - loss: 0.0035 - 43ms/epoch - 4ms/step
# Epoch 370/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 371/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 372/5000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 373/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 374/5000
# 11/11 - 0s - loss: 0.0034 - 37ms/epoch - 3ms/step
# Epoch 375/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 376/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 377/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 378/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 379/5000
# 11/11 - 0s - loss: 0.0032 - 41ms/epoch - 4ms/step
# Epoch 380/5000
# 11/11 - 0s - loss: 0.0032 - 38ms/epoch - 3ms/step
# Epoch 381/5000
# 11/11 - 0s - loss: 0.0033 - 38ms/epoch - 3ms/step
# Epoch 382/5000
# 11/11 - 0s - loss: 0.0036 - 35ms/epoch - 3ms/step
# Epoch 383/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 384/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 385/5000
# 11/11 - 0s - loss: 0.0032 - 43ms/epoch - 4ms/step
# Epoch 386/5000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 387/5000
# 11/11 - 0s - loss: 0.0035 - 37ms/epoch - 3ms/step
# Epoch 388/5000
# 11/11 - 0s - loss: 0.0031 - 38ms/epoch - 3ms/step
# Epoch 389/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 390/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 391/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 392/5000
# 11/11 - 0s - loss: 0.0032 - 30ms/epoch - 3ms/step
# Epoch 393/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 394/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 395/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 396/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 397/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 398/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 399/5000
# 11/11 - 0s - loss: 0.0034 - 35ms/epoch - 3ms/step
# Epoch 400/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 401/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 402/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 403/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 404/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 405/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 406/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 407/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 408/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 409/5000
# 11/11 - 0s - loss: 0.0037 - 35ms/epoch - 3ms/step
# Epoch 410/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 411/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 412/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 413/5000
# 11/11 - 0s - loss: 0.0039 - 36ms/epoch - 3ms/step
# Epoch 414/5000
# 11/11 - 0s - loss: 0.0037 - 35ms/epoch - 3ms/step
# Epoch 415/5000
# 11/11 - 0s - loss: 0.0034 - 33ms/epoch - 3ms/step
# Epoch 416/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 417/5000
# 11/11 - 0s - loss: 0.0033 - 37ms/epoch - 3ms/step
# Epoch 418/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 419/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 420/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 421/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 422/5000
# 11/11 - 0s - loss: 0.0032 - 39ms/epoch - 4ms/step
# Epoch 423/5000
# 11/11 - 0s - loss: 0.0036 - 35ms/epoch - 3ms/step
# Epoch 424/5000
# 11/11 - 0s - loss: 0.0032 - 31ms/epoch - 3ms/step
# Epoch 425/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 426/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 427/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 428/5000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 429/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 430/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 431/5000
# 11/11 - 0s - loss: 0.0032 - 31ms/epoch - 3ms/step
# Epoch 432/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 433/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 434/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 435/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 436/5000
# 11/11 - 0s - loss: 0.0035 - 34ms/epoch - 3ms/step
# Epoch 437/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 438/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 439/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 440/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 441/5000
# 11/11 - 0s - loss: 0.0033 - 33ms/epoch - 3ms/step
# Epoch 442/5000
# 11/11 - 0s - loss: 0.0036 - 34ms/epoch - 3ms/step
# Epoch 443/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 444/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 445/5000
# 11/11 - 0s - loss: 0.0033 - 38ms/epoch - 3ms/step
# Epoch 446/5000
# 11/11 - 0s - loss: 0.0033 - 38ms/epoch - 3ms/step
# Epoch 447/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 448/5000
# 11/11 - 0s - loss: 0.0035 - 38ms/epoch - 3ms/step
# Epoch 449/5000
# 11/11 - 0s - loss: 0.0034 - 39ms/epoch - 4ms/step
# Epoch 450/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 451/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 452/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 453/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 454/5000
# 11/11 - 0s - loss: 0.0033 - 33ms/epoch - 3ms/step
# Epoch 455/5000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 456/5000
# 11/11 - 0s - loss: 0.0032 - 35ms/epoch - 3ms/step
# Epoch 457/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 458/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 459/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 460/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 461/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 462/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 463/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 464/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 465/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 466/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 467/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 468/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 469/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 470/5000
# 11/11 - 0s - loss: 0.0031 - 48ms/epoch - 4ms/step
# Epoch 471/5000
# 11/11 - 0s - loss: 0.0037 - 66ms/epoch - 6ms/step
# Epoch 472/5000
# 11/11 - 0s - loss: 0.0036 - 37ms/epoch - 3ms/step
# Epoch 473/5000
# 11/11 - 0s - loss: 0.0032 - 46ms/epoch - 4ms/step
# Epoch 474/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 475/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 476/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 477/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 478/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 479/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 480/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 481/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 482/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 483/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 484/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 485/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 486/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 487/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 488/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 489/5000
# 11/11 - 0s - loss: 0.0035 - 35ms/epoch - 3ms/step
# Epoch 490/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 491/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 492/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 493/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 494/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 495/5000
# 11/11 - 0s - loss: 0.0031 - 42ms/epoch - 4ms/step
# Epoch 496/5000
# 11/11 - 0s - loss: 0.0033 - 37ms/epoch - 3ms/step
# Epoch 497/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 498/5000
# 11/11 - 0s - loss: 0.0033 - 35ms/epoch - 3ms/step
# Epoch 499/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 500/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 501/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 502/5000
# 11/11 - 0s - loss: 0.0033 - 32ms/epoch - 3ms/step
# Epoch 503/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 504/5000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 505/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 506/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 507/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 508/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 509/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 510/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 511/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 512/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 513/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 514/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 515/5000
# 11/11 - 0s - loss: 0.0032 - 31ms/epoch - 3ms/step
# Epoch 516/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 517/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 518/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 519/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 520/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 521/5000
# 11/11 - 0s - loss: 0.0034 - 35ms/epoch - 3ms/step
# Epoch 522/5000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 523/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 524/5000
# 11/11 - 0s - loss: 0.0030 - 40ms/epoch - 4ms/step
# Epoch 525/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 526/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 527/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 528/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 529/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 530/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 531/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 532/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 533/5000
# 11/11 - 0s - loss: 0.0032 - 32ms/epoch - 3ms/step
# Epoch 534/5000
# 11/11 - 0s - loss: 0.0032 - 31ms/epoch - 3ms/step
# Epoch 535/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 536/5000
# 11/11 - 0s - loss: 0.0030 - 30ms/epoch - 3ms/step
# Epoch 537/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 538/5000
# 11/11 - 0s - loss: 0.0032 - 32ms/epoch - 3ms/step
# Epoch 539/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 540/5000
# 11/11 - 0s - loss: 0.0031 - 30ms/epoch - 3ms/step
# Epoch 541/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 542/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 543/5000
# 11/11 - 0s - loss: 0.0035 - 36ms/epoch - 3ms/step
# Epoch 544/5000
# 11/11 - 0s - loss: 0.0031 - 38ms/epoch - 3ms/step
# Epoch 545/5000
# 11/11 - 0s - loss: 0.0032 - 32ms/epoch - 3ms/step
# Epoch 546/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 547/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 548/5000
# 11/11 - 0s - loss: 0.0030 - 31ms/epoch - 3ms/step
# Epoch 549/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 550/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 551/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 552/5000
# 11/11 - 0s - loss: 0.0032 - 32ms/epoch - 3ms/step
# Epoch 553/5000
# 11/11 - 0s - loss: 0.0033 - 32ms/epoch - 3ms/step
# Epoch 554/5000
# 11/11 - 0s - loss: 0.0031 - 31ms/epoch - 3ms/step
# Epoch 555/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 556/5000
# 11/11 - 0s - loss: 0.0035 - 31ms/epoch - 3ms/step
# Epoch 557/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 558/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 559/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 560/5000
# 11/11 - 0s - loss: 0.0031 - 29ms/epoch - 3ms/step
# Epoch 561/5000
# 11/11 - 0s - loss: 0.0032 - 37ms/epoch - 3ms/step
# Epoch 562/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 563/5000
# 11/11 - 0s - loss: 0.0034 - 31ms/epoch - 3ms/step
# Epoch 564/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 565/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 566/5000
# 11/11 - 0s - loss: 0.0030 - 30ms/epoch - 3ms/step
# Epoch 567/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 568/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 569/5000
# 11/11 - 0s - loss: 0.0034 - 35ms/epoch - 3ms/step
# Epoch 570/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 571/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 572/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 573/5000
# 11/11 - 0s - loss: 0.0030 - 31ms/epoch - 3ms/step
# Epoch 574/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 575/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 576/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 577/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 578/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 579/5000
# 11/11 - 0s - loss: 0.0035 - 35ms/epoch - 3ms/step
# Epoch 580/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 581/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 582/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 583/5000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 584/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 585/5000
# 11/11 - 0s - loss: 0.0034 - 38ms/epoch - 3ms/step
# Epoch 586/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 587/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 588/5000
# 11/11 - 0s - loss: 0.0035 - 34ms/epoch - 3ms/step
# Epoch 589/5000
# 11/11 - 0s - loss: 0.0032 - 32ms/epoch - 3ms/step
# Epoch 590/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 591/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 592/5000
# 11/11 - 0s - loss: 0.0032 - 38ms/epoch - 3ms/step
# Epoch 593/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 594/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 595/5000
# 11/11 - 0s - loss: 0.0033 - 36ms/epoch - 3ms/step
# Epoch 596/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 597/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 598/5000
# 11/11 - 0s - loss: 0.0032 - 35ms/epoch - 3ms/step
# Epoch 599/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 600/5000
# 11/11 - 0s - loss: 0.0034 - 33ms/epoch - 3ms/step
# Epoch 601/5000
# 11/11 - 0s - loss: 0.0034 - 32ms/epoch - 3ms/step
# Epoch 602/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 603/5000
# 11/11 - 0s - loss: 0.0032 - 34ms/epoch - 3ms/step
# Epoch 604/5000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 605/5000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 606/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 607/5000
# 11/11 - 0s - loss: 0.0031 - 38ms/epoch - 3ms/step
# Epoch 608/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 609/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 610/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 611/5000
# 11/11 - 0s - loss: 0.0029 - 34ms/epoch - 3ms/step
# Epoch 612/5000
# 11/11 - 0s - loss: 0.0030 - 32ms/epoch - 3ms/step
# Epoch 613/5000
# 11/11 - 0s - loss: 0.0029 - 36ms/epoch - 3ms/step
# Epoch 614/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 615/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 616/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 617/5000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 618/5000
# 11/11 - 0s - loss: 0.0032 - 35ms/epoch - 3ms/step
# Epoch 619/5000
# 11/11 - 0s - loss: 0.0035 - 33ms/epoch - 3ms/step
# Epoch 620/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 621/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 622/5000
# 11/11 - 0s - loss: 0.0032 - 42ms/epoch - 4ms/step
# Epoch 623/5000
# 11/11 - 0s - loss: 0.0033 - 33ms/epoch - 3ms/step
# Epoch 624/5000
# 11/11 - 0s - loss: 0.0036 - 36ms/epoch - 3ms/step
# Epoch 625/5000
# 11/11 - 0s - loss: 0.0035 - 33ms/epoch - 3ms/step
# Epoch 626/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 627/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 628/5000
# 11/11 - 0s - loss: 0.0029 - 34ms/epoch - 3ms/step
# Epoch 629/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 630/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 631/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 632/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 633/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 634/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 635/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 636/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 637/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 638/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 639/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 640/5000
# 11/11 - 0s - loss: 0.0031 - 32ms/epoch - 3ms/step
# Epoch 641/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 642/5000
# 11/11 - 0s - loss: 0.0030 - 36ms/epoch - 3ms/step
# Epoch 643/5000
# 11/11 - 0s - loss: 0.0032 - 37ms/epoch - 3ms/step
# Epoch 644/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 645/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 646/5000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 647/5000
# 11/11 - 0s - loss: 0.0032 - 37ms/epoch - 3ms/step
# Epoch 648/5000
# 11/11 - 0s - loss: 0.0036 - 34ms/epoch - 3ms/step
# Epoch 649/5000
# 11/11 - 0s - loss: 0.0035 - 33ms/epoch - 3ms/step
# Epoch 650/5000
# 11/11 - 0s - loss: 0.0038 - 36ms/epoch - 3ms/step
# Epoch 651/5000
# 11/11 - 0s - loss: 0.0039 - 36ms/epoch - 3ms/step
# Epoch 652/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 653/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 654/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 655/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 656/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 657/5000
# 11/11 - 0s - loss: 0.0033 - 33ms/epoch - 3ms/step
# Epoch 658/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 659/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 660/5000
# 11/11 - 0s - loss: 0.0030 - 33ms/epoch - 3ms/step
# Epoch 661/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 662/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 663/5000
# 11/11 - 0s - loss: 0.0032 - 35ms/epoch - 3ms/step
# Epoch 664/5000
# 11/11 - 0s - loss: 0.0036 - 38ms/epoch - 3ms/step
# Epoch 665/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 666/5000
# 11/11 - 0s - loss: 0.0032 - 35ms/epoch - 3ms/step
# Epoch 667/5000
# 11/11 - 0s - loss: 0.0034 - 34ms/epoch - 3ms/step
# Epoch 668/5000
# 11/11 - 0s - loss: 0.0029 - 34ms/epoch - 3ms/step
# Epoch 669/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 670/5000
# 11/11 - 0s - loss: 0.0033 - 39ms/epoch - 4ms/step
# Epoch 671/5000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 672/5000
# 11/11 - 0s - loss: 0.0031 - 49ms/epoch - 4ms/step
# Epoch 673/5000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 674/5000
# 11/11 - 0s - loss: 0.0032 - 37ms/epoch - 3ms/step
# Epoch 675/5000
# 11/11 - 0s - loss: 0.0033 - 38ms/epoch - 3ms/step
# Epoch 676/5000
# 11/11 - 0s - loss: 0.0036 - 36ms/epoch - 3ms/step
# Epoch 677/5000
# 11/11 - 0s - loss: 0.0032 - 38ms/epoch - 3ms/step
# Epoch 678/5000
# 11/11 - 0s - loss: 0.0032 - 38ms/epoch - 3ms/step
# Epoch 679/5000
# 11/11 - 0s - loss: 0.0029 - 39ms/epoch - 4ms/step
# Epoch 680/5000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 681/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 682/5000
# 11/11 - 0s - loss: 0.0032 - 39ms/epoch - 4ms/step
# Epoch 683/5000
# 11/11 - 0s - loss: 0.0029 - 35ms/epoch - 3ms/step
# Epoch 684/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 685/5000
# 11/11 - 0s - loss: 0.0032 - 36ms/epoch - 3ms/step
# Epoch 686/5000
# 11/11 - 0s - loss: 0.0030 - 36ms/epoch - 3ms/step
# Epoch 687/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 688/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 689/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 690/5000
# 11/11 - 0s - loss: 0.0031 - 42ms/epoch - 4ms/step
# Epoch 691/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 692/5000
# 11/11 - 0s - loss: 0.0029 - 34ms/epoch - 3ms/step
# Epoch 693/5000
# 11/11 - 0s - loss: 0.0034 - 39ms/epoch - 4ms/step
# Epoch 694/5000
# 11/11 - 0s - loss: 0.0033 - 37ms/epoch - 3ms/step
# Epoch 695/5000
# 11/11 - 0s - loss: 0.0034 - 36ms/epoch - 3ms/step
# Epoch 696/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 697/5000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 698/5000
# 11/11 - 0s - loss: 0.0029 - 36ms/epoch - 3ms/step
# Epoch 699/5000
# 11/11 - 0s - loss: 0.0029 - 35ms/epoch - 3ms/step
# Epoch 700/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 701/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 702/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 703/5000
# 11/11 - 0s - loss: 0.0033 - 36ms/epoch - 3ms/step
# Epoch 704/5000
# 11/11 - 0s - loss: 0.0036 - 35ms/epoch - 3ms/step
# Epoch 705/5000
# 11/11 - 0s - loss: 0.0040 - 34ms/epoch - 3ms/step
# Epoch 706/5000
# 11/11 - 0s - loss: 0.0034 - 37ms/epoch - 3ms/step
# Epoch 707/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 708/5000
# 11/11 - 0s - loss: 0.0030 - 36ms/epoch - 3ms/step
# Epoch 709/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 710/5000
# 11/11 - 0s - loss: 0.0031 - 35ms/epoch - 3ms/step
# Epoch 711/5000
# 11/11 - 0s - loss: 0.0032 - 33ms/epoch - 3ms/step
# Epoch 712/5000
# 11/11 - 0s - loss: 0.0033 - 34ms/epoch - 3ms/step
# Epoch 713/5000
# 11/11 - 0s - loss: 0.0029 - 35ms/epoch - 3ms/step
# Epoch 714/5000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 715/5000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 716/5000
# 11/11 - 0s - loss: 0.0030 - 35ms/epoch - 3ms/step
# Epoch 717/5000
# 11/11 - 0s - loss: 0.0030 - 36ms/epoch - 3ms/step
# Epoch 718/5000
# 11/11 - 0s - loss: 0.0031 - 36ms/epoch - 3ms/step
# Epoch 719/5000
# 11/11 - 0s - loss: 0.0029 - 38ms/epoch - 3ms/step
# Epoch 720/5000
# 11/11 - 0s - loss: 0.0030 - 34ms/epoch - 3ms/step
# Epoch 721/5000
# 11/11 - 0s - loss: 0.0031 - 34ms/epoch - 3ms/step
# Epoch 722/5000
# 11/11 - 0s - loss: 0.0032 - 39ms/epoch - 4ms/step
# Epoch 723/5000
# 11/11 - 0s - loss: 0.0029 - 45ms/epoch - 4ms/step
# Epoch 724/5000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 725/5000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 726/5000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 727/5000
# 11/11 - 0s - loss: 0.0030 - 36ms/epoch - 3ms/step
# Epoch 728/5000
# 11/11 - 0s - loss: 0.0029 - 35ms/epoch - 3ms/step
# Epoch 729/5000
# 11/11 - 0s - loss: 0.0029 - 36ms/epoch - 3ms/step
# Epoch 730/5000
# ...
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4761/5000
# 11/11 - 0s - loss: 0.0024 - 36ms/epoch - 3ms/step
# Epoch 4762/5000
# 11/11 - 0s - loss: 0.0024 - 36ms/epoch - 3ms/step
# Epoch 4763/5000
# 11/11 - 0s - loss: 0.0023 - 53ms/epoch - 5ms/step
# Epoch 4764/5000
# 11/11 - 0s - loss: 0.0024 - 41ms/epoch - 4ms/step
# Epoch 4765/5000
# 11/11 - 0s - loss: 0.0025 - 49ms/epoch - 4ms/step
# Epoch 4766/5000
# 11/11 - 0s - loss: 0.0024 - 37ms/epoch - 3ms/step
# Epoch 4767/5000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 4768/5000
# 11/11 - 0s - loss: 0.0024 - 34ms/epoch - 3ms/step
# Epoch 4769/5000
# 11/11 - 0s - loss: 0.0023 - 34ms/epoch - 3ms/step
# Epoch 4770/5000
# 11/11 - 0s - loss: 0.0025 - 32ms/epoch - 3ms/step
# Epoch 4771/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4772/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4773/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4774/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4775/5000
# 11/11 - 0s - loss: 0.0027 - 40ms/epoch - 4ms/step
# Epoch 4776/5000
# 11/11 - 0s - loss: 0.0024 - 34ms/epoch - 3ms/step
# Epoch 4777/5000
# 11/11 - 0s - loss: 0.0026 - 30ms/epoch - 3ms/step
# Epoch 4778/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4779/5000
# 11/11 - 0s - loss: 0.0024 - 35ms/epoch - 3ms/step
# Epoch 4780/5000
# 11/11 - 0s - loss: 0.0027 - 30ms/epoch - 3ms/step
# Epoch 4781/5000
# 11/11 - 0s - loss: 0.0026 - 32ms/epoch - 3ms/step
# Epoch 4782/5000
# 11/11 - 0s - loss: 0.0028 - 34ms/epoch - 3ms/step
# Epoch 4783/5000
# 11/11 - 0s - loss: 0.0025 - 30ms/epoch - 3ms/step
# Epoch 4784/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4785/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4786/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4787/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4788/5000
# 11/11 - 0s - loss: 0.0025 - 29ms/epoch - 3ms/step
# Epoch 4789/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4790/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4791/5000
# 11/11 - 0s - loss: 0.0023 - 34ms/epoch - 3ms/step
# Epoch 4792/5000
# 11/11 - 0s - loss: 0.0024 - 34ms/epoch - 3ms/step
# Epoch 4793/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4794/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4795/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4796/5000
# 11/11 - 0s - loss: 0.0023 - 32ms/epoch - 3ms/step
# Epoch 4797/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4798/5000
# 11/11 - 0s - loss: 0.0026 - 31ms/epoch - 3ms/step
# Epoch 4799/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4800/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4801/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4802/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4803/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4804/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4805/5000
# 11/11 - 0s - loss: 0.0025 - 42ms/epoch - 4ms/step
# Epoch 4806/5000
# 11/11 - 0s - loss: 0.0023 - 32ms/epoch - 3ms/step
# Epoch 4807/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4808/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4809/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4810/5000
# 11/11 - 0s - loss: 0.0026 - 31ms/epoch - 3ms/step
# Epoch 4811/5000
# 11/11 - 0s - loss: 0.0028 - 32ms/epoch - 3ms/step
# Epoch 4812/5000
# 11/11 - 0s - loss: 0.0025 - 31ms/epoch - 3ms/step
# Epoch 4813/5000
# 11/11 - 0s - loss: 0.0024 - 35ms/epoch - 3ms/step
# Epoch 4814/5000
# 11/11 - 0s - loss: 0.0023 - 36ms/epoch - 3ms/step
# Epoch 4815/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4816/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4817/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4818/5000
# 11/11 - 0s - loss: 0.0024 - 35ms/epoch - 3ms/step
# Epoch 4819/5000
# 11/11 - 0s - loss: 0.0025 - 31ms/epoch - 3ms/step
# Epoch 4820/5000
# 11/11 - 0s - loss: 0.0024 - 34ms/epoch - 3ms/step
# Epoch 4821/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4822/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4823/5000
# 11/11 - 0s - loss: 0.0025 - 33ms/epoch - 3ms/step
# Epoch 4824/5000
# 11/11 - 0s - loss: 0.0023 - 34ms/epoch - 3ms/step
# Epoch 4825/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4826/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4827/5000
# 11/11 - 0s - loss: 0.0025 - 31ms/epoch - 3ms/step
# Epoch 4828/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4829/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4830/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4831/5000
# 11/11 - 0s - loss: 0.0028 - 31ms/epoch - 3ms/step
# Epoch 4832/5000
# 11/11 - 0s - loss: 0.0026 - 34ms/epoch - 3ms/step
# Epoch 4833/5000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 4834/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4835/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4836/5000
# 11/11 - 0s - loss: 0.0022 - 29ms/epoch - 3ms/step
# Epoch 4837/5000
# 11/11 - 0s - loss: 0.0023 - 32ms/epoch - 3ms/step
# Epoch 4838/5000
# 11/11 - 0s - loss: 0.0023 - 32ms/epoch - 3ms/step
# Epoch 4839/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4840/5000
# 11/11 - 0s - loss: 0.0024 - 33ms/epoch - 3ms/step
# Epoch 4841/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4842/5000
# 11/11 - 0s - loss: 0.0025 - 32ms/epoch - 3ms/step
# Epoch 4843/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4844/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4845/5000
# 11/11 - 0s - loss: 0.0024 - 34ms/epoch - 3ms/step
# Epoch 4846/5000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 4847/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4848/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4849/5000
# 11/11 - 0s - loss: 0.0025 - 30ms/epoch - 3ms/step
# Epoch 4850/5000
# 11/11 - 0s - loss: 0.0031 - 33ms/epoch - 3ms/step
# Epoch 4851/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4852/5000
# 11/11 - 0s - loss: 0.0023 - 34ms/epoch - 3ms/step
# Epoch 4853/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4854/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4855/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4856/5000
# 11/11 - 0s - loss: 0.0028 - 33ms/epoch - 3ms/step
# Epoch 4857/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4858/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4859/5000
# 11/11 - 0s - loss: 0.0023 - 36ms/epoch - 3ms/step
# Epoch 4860/5000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 4861/5000
# 11/11 - 0s - loss: 0.0026 - 33ms/epoch - 3ms/step
# Epoch 4862/5000
# 11/11 - 0s - loss: 0.0022 - 32ms/epoch - 3ms/step
# Epoch 4863/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4864/5000
# 11/11 - 0s - loss: 0.0025 - 30ms/epoch - 3ms/step
# Epoch 4865/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4866/5000
# 11/11 - 0s - loss: 0.0025 - 32ms/epoch - 3ms/step
# Epoch 4867/5000
# 11/11 - 0s - loss: 0.0028 - 32ms/epoch - 3ms/step
# Epoch 4868/5000
# 11/11 - 0s - loss: 0.0024 - 33ms/epoch - 3ms/step
# Epoch 4869/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4870/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4871/5000
# 11/11 - 0s - loss: 0.0023 - 36ms/epoch - 3ms/step
# Epoch 4872/5000
# 11/11 - 0s - loss: 0.0023 - 42ms/epoch - 4ms/step
# Epoch 4873/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4874/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4875/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4876/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4877/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4878/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4879/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4880/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4881/5000
# 11/11 - 0s - loss: 0.0025 - 30ms/epoch - 3ms/step
# Epoch 4882/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4883/5000
# 11/11 - 0s - loss: 0.0026 - 32ms/epoch - 3ms/step
# Epoch 4884/5000
# 11/11 - 0s - loss: 0.0027 - 36ms/epoch - 3ms/step
# Epoch 4885/5000
# 11/11 - 0s - loss: 0.0024 - 45ms/epoch - 4ms/step
# Epoch 4886/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4887/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4888/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4889/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4890/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4891/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4892/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4893/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4894/5000
# 11/11 - 0s - loss: 0.0026 - 32ms/epoch - 3ms/step
# Epoch 4895/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4896/5000
# 11/11 - 0s - loss: 0.0024 - 32ms/epoch - 3ms/step
# Epoch 4897/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4898/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4899/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4900/5000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 4901/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4902/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4903/5000
# 11/11 - 0s - loss: 0.0023 - 33ms/epoch - 3ms/step
# Epoch 4904/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4905/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4906/5000
# 11/11 - 0s - loss: 0.0026 - 29ms/epoch - 3ms/step
# Epoch 4907/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4908/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4909/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4910/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4911/5000
# 11/11 - 0s - loss: 0.0025 - 29ms/epoch - 3ms/step
# Epoch 4912/5000
# 11/11 - 0s - loss: 0.0025 - 30ms/epoch - 3ms/step
# Epoch 4913/5000
# 11/11 - 0s - loss: 0.0025 - 35ms/epoch - 3ms/step
# Epoch 4914/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4915/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4916/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4917/5000
# 11/11 - 0s - loss: 0.0023 - 27ms/epoch - 2ms/step
# Epoch 4918/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4919/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4920/5000
# 11/11 - 0s - loss: 0.0022 - 31ms/epoch - 3ms/step
# Epoch 4921/5000
# 11/11 - 0s - loss: 0.0022 - 32ms/epoch - 3ms/step
# Epoch 4922/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4923/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4924/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4925/5000
# 11/11 - 0s - loss: 0.0024 - 28ms/epoch - 3ms/step
# Epoch 4926/5000
# 11/11 - 0s - loss: 0.0025 - 32ms/epoch - 3ms/step
# Epoch 4927/5000
# 11/11 - 0s - loss: 0.0023 - 35ms/epoch - 3ms/step
# Epoch 4928/5000
# 11/11 - 0s - loss: 0.0024 - 28ms/epoch - 3ms/step
# Epoch 4929/5000
# 11/11 - 0s - loss: 0.0026 - 27ms/epoch - 2ms/step
# Epoch 4930/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4931/5000
# 11/11 - 0s - loss: 0.0022 - 30ms/epoch - 3ms/step
# Epoch 4932/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4933/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4934/5000
# 11/11 - 0s - loss: 0.0023 - 27ms/epoch - 2ms/step
# Epoch 4935/5000
# 11/11 - 0s - loss: 0.0022 - 30ms/epoch - 3ms/step
# Epoch 4936/5000
# 11/11 - 0s - loss: 0.0023 - 26ms/epoch - 2ms/step
# Epoch 4937/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4938/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4939/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4940/5000
# 11/11 - 0s - loss: 0.0028 - 39ms/epoch - 4ms/step
# Epoch 4941/5000
# 11/11 - 0s - loss: 0.0028 - 30ms/epoch - 3ms/step
# Epoch 4942/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4943/5000
# 11/11 - 0s - loss: 0.0027 - 27ms/epoch - 2ms/step
# Epoch 4944/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4945/5000
# 11/11 - 0s - loss: 0.0025 - 27ms/epoch - 2ms/step
# Epoch 4946/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4947/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4948/5000
# 11/11 - 0s - loss: 0.0024 - 30ms/epoch - 3ms/step
# Epoch 4949/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4950/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4951/5000
# 11/11 - 0s - loss: 0.0025 - 28ms/epoch - 3ms/step
# Epoch 4952/5000
# 11/11 - 0s - loss: 0.0026 - 39ms/epoch - 4ms/step
# Epoch 4953/5000
# 11/11 - 0s - loss: 0.0025 - 32ms/epoch - 3ms/step
# Epoch 4954/5000
# 11/11 - 0s - loss: 0.0025 - 28ms/epoch - 3ms/step
# Epoch 4955/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4956/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4957/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4958/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4959/5000
# 11/11 - 0s - loss: 0.0024 - 28ms/epoch - 3ms/step
# Epoch 4960/5000
# 11/11 - 0s - loss: 0.0025 - 33ms/epoch - 3ms/step
# Epoch 4961/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4962/5000
# 11/11 - 0s - loss: 0.0027 - 28ms/epoch - 3ms/step
# Epoch 4963/5000
# 11/11 - 0s - loss: 0.0024 - 28ms/epoch - 3ms/step
# Epoch 4964/5000
# 11/11 - 0s - loss: 0.0023 - 32ms/epoch - 3ms/step
# Epoch 4965/5000
# 11/11 - 0s - loss: 0.0025 - 37ms/epoch - 3ms/step
# Epoch 4966/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4967/5000
# 11/11 - 0s - loss: 0.0023 - 27ms/epoch - 2ms/step
# Epoch 4968/5000
# 11/11 - 0s - loss: 0.0022 - 29ms/epoch - 3ms/step
# Epoch 4969/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4970/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4971/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4972/5000
# 11/11 - 0s - loss: 0.0025 - 28ms/epoch - 3ms/step
# Epoch 4973/5000
# 11/11 - 0s - loss: 0.0022 - 31ms/epoch - 3ms/step
# Epoch 4974/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4975/5000
# 11/11 - 0s - loss: 0.0026 - 28ms/epoch - 3ms/step
# Epoch 4976/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4977/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4978/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# Epoch 4979/5000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 4980/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4981/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4982/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4983/5000
# 11/11 - 0s - loss: 0.0026 - 30ms/epoch - 3ms/step
# Epoch 4984/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4985/5000
# 11/11 - 0s - loss: 0.0024 - 29ms/epoch - 3ms/step
# Epoch 4986/5000
# 11/11 - 0s - loss: 0.0022 - 30ms/epoch - 3ms/step
# Epoch 4987/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4988/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4989/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4990/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4991/5000
# 11/11 - 0s - loss: 0.0026 - 28ms/epoch - 3ms/step
# Epoch 4992/5000
# 11/11 - 0s - loss: 0.0027 - 35ms/epoch - 3ms/step
# Epoch 4993/5000
# 11/11 - 0s - loss: 0.0027 - 36ms/epoch - 3ms/step
# Epoch 4994/5000
# 11/11 - 0s - loss: 0.0024 - 31ms/epoch - 3ms/step
# Epoch 4995/5000
# 11/11 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 4996/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 4997/5000
# 11/11 - 0s - loss: 0.0024 - 28ms/epoch - 3ms/step
# Epoch 4998/5000
# 11/11 - 0s - loss: 0.0023 - 31ms/epoch - 3ms/step
# Epoch 4999/5000
# 11/11 - 0s - loss: 0.0023 - 30ms/epoch - 3ms/step
# Epoch 5000/5000
# 11/11 - 0s - loss: 0.0023 - 28ms/epoch - 3ms/step
# it took 0:02:50.344706 (sec) to calibrate the model
# 15/15 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Use different activation functions

# %%
model = lm.main()

xs, ys, xs_c, ys_c = ld.bathtub()

model.summary()

t1 = now()
print(t1)

model.optimizer.learning_rate.assign(0.002)
h = model.fit([xs_c], [ys_c], epochs = 500,  verbose = 2)

t2 = now()
print('it took', t2 - t1, '(sec) to calibrate the model')

# plot some results
plt.figure(1, dpi=150)
plt.semilogy(h.history['loss'], label='training loss')
plt.grid(which='both')
plt.xlabel('calibration epoch')
plt.ylabel('log$_{10}$ MSE')
plt.legend()

plt.figure(2, dpi=300)
plt.scatter(xs_c[::10], ys_c[::10], c='green', label = 'calibration data')
plt.plot(xs, ys, c='black', linestyle='--', label='bathtub function')
plt.plot(xs, model.predict(xs), label='model', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
